# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
image_size = 28
num_labels = 10
num_channels = 1
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)



def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
with graph.as_default():

  
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size  * image_size  * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  

  def model(data):
  
    conv1 = tf.nn.atrous_conv2d(data, layer1_weights, 2, padding='SAME')
    hidden1 = tf.nn.relu(conv1 + layer1_biases)
    conv2 = tf.nn.atrous_conv2d(hidden1, layer2_weights, 4 , padding='SAME')
    hidden2 = tf.nn.relu(conv2 + layer2_biases)
    shape = hidden2.get_shape().as_list()
    reshape = tf.reshape(hidden2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden3 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden3, layer4_weights) + layer4_biases
  

  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  

  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
  
  
num_steps = 15000

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):

        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)

        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}#, keep_prob : 0.5}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step {}: {}".format(step, l))
            print("Minibatch accuracy: {:.1f}".format(accuracy(predictions, batch_labels)))
            print("Validation accuracy: {:.1f}".format(accuracy(valid_prediction.eval(), valid_labels)))
    print("Test accuracy: {:.1f}".format(accuracy(test_prediction.eval(), test_labels)))
# Out:
# WARNING:tensorflow:From C:\Users\ashut\Anaconda3\envs\deep1.3\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.336408615112305
# Minibatch accuracy: 12.5
# Validation accuracy: 10.1
# Minibatch loss at step 500: 0.7661195397377014
# Minibatch accuracy: 81.2
# Validation accuracy: 80.0
# Minibatch loss at step 1000: 0.5056911110877991
# Minibatch accuracy: 87.5
# Validation accuracy: 81.6
# Minibatch loss at step 1500: 0.49353086948394775
# Minibatch accuracy: 81.2
# Validation accuracy: 82.3
# Minibatch loss at step 2000: 0.12614673376083374
# Minibatch accuracy: 93.8
# Validation accuracy: 84.4
# Minibatch loss at step 2500: 0.8621289730072021
# Minibatch accuracy: 68.8
# Validation accuracy: 84.6
# Minibatch loss at step 3000: 0.7059618830680847
# Minibatch accuracy: 81.2
# Validation accuracy: 85.3
# Minibatch loss at step 3500: 0.6418355703353882
# Minibatch accuracy: 75.0
# Validation accuracy: 85.3
# Minibatch loss at step 4000: 0.4703189730644226
# Minibatch accuracy: 81.2
# Validation accuracy: 85.8
# Minibatch loss at step 4500: 0.5513014793395996
# Minibatch accuracy: 81.2
# Validation accuracy: 86.4
# Minibatch loss at step 5000: 1.217397689819336
# Minibatch accuracy: 75.0
# Validation accuracy: 85.8
# Minibatch loss at step 5500: 0.5042887926101685
# Minibatch accuracy: 87.5
# Validation accuracy: 86.3
# Minibatch loss at step 6000: 0.15535345673561096
# Minibatch accuracy: 100.0
# Validation accuracy: 86.2
# Minibatch loss at step 6500: 0.6246418356895447
# Minibatch accuracy: 75.0
# Validation accuracy: 86.5
# Minibatch loss at step 7000: 0.882325291633606
# Minibatch accuracy: 68.8
# Validation accuracy: 86.8
# Minibatch loss at step 7500: 0.23713189363479614
# Minibatch accuracy: 93.8
# Validation accuracy: 86.8
# Minibatch loss at step 8000: 0.5248398780822754
# Minibatch accuracy: 81.2
# Validation accuracy: 87.3
# Minibatch loss at step 8500: 0.2704636752605438
# Minibatch accuracy: 87.5
# Validation accuracy: 87.2
# Minibatch loss at step 9000: 0.08405382931232452
# Minibatch accuracy: 100.0
# Validation accuracy: 87.5
# Minibatch loss at step 9500: 0.06260819733142853
# Minibatch accuracy: 100.0
# Validation accuracy: 87.7
# Minibatch loss at step 10000: 0.19010689854621887
# Minibatch accuracy: 93.8
# Validation accuracy: 87.9
# Minibatch loss at step 10500: 0.4393942952156067
# Minibatch accuracy: 81.2
# Validation accuracy: 87.7
# Minibatch loss at step 11000: 0.2024337649345398
# Minibatch accuracy: 93.8
# Validation accuracy: 87.2
# Minibatch loss at step 11500: 0.29063093662261963
# Minibatch accuracy: 87.5
# Validation accuracy: 88.0
# Minibatch loss at step 12000: 0.49640947580337524
# Minibatch accuracy: 87.5
# Validation accuracy: 88.0
# Minibatch loss at step 12500: 0.9270360469818115
# Minibatch accuracy: 75.0
# Validation accuracy: 88.1
# Minibatch loss at step 13000: 0.24829627573490143
# Minibatch accuracy: 93.8
# Validation accuracy: 88.2
# Minibatch loss at step 13500: 0.30331629514694214
# Minibatch accuracy: 93.8
# Validation accuracy: 88.4
# Minibatch loss at step 14000: 0.03454301506280899
# Minibatch accuracy: 100.0
# Validation accuracy: 88.6
# Minibatch loss at step 14500: 0.4682404696941376
# Minibatch accuracy: 81.2
# Validation accuracy: 88.4
# Test accuracy: 94.3
